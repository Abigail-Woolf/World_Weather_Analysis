# %% [markdown]
# # Challenge: Part 1- Get the weather description and amount of precipication for each city

# %%
# Import the dependencies.
from citipy import citipy
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 620

# %%
# Import the request library
import requests
from datetime import datetime
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-" * 25)

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for index, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data: max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
        try:
            city_rain_inches=city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches=0
        try:
            city_snow_inches=city_weather["rain"]["1h"]
        except KeyError:
            city_snow_inches=0
            
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-" * 20)
print("Data Retrieval Complete      ")
print("-" * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | natchez
# Processing Record 2 of Set 1 | richards bay
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | seoul
# Processing Record 5 of Set 1 | berlevag
# Processing Record 6 of Set 1 | novyy urengoy
# Processing Record 7 of Set 1 | guia lopes da laguna
# Processing Record 8 of Set 1 | kupang
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | gizo
# Processing Record 11 of Set 1 | saint-denis
# Processing Record 12 of Set 1 | port lincoln
# Processing Record 13 of Set 1 | vila velha
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | lahij
# Processing Record 16 of Set 1 | carlsbad
# Processing Record 17 of Set 1 | kavaratti
# Processing Record 18 of Set 1 | katsiveli
# City not found. Skipping...
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | chimore
# Processing Record 22 of Set 1 | buala
# Processing Record 23 of Set 1 | isangel
# Processing Record 24 of Set 1 | vaitape
# Processing Record 25 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | las guacamayas
# Processing Record 28 of Set 1 | tournai
# Processing Record 29 of Set 1 | chapulhuacan
# Processing Record 30 of Set 1 | neftekumsk
# Processing Record 31 of Set 1 | granadilla de abona
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | pouebo
# Processing Record 34 of Set 1 | svetlaya
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | marfino
# Processing Record 40 of Set 1 | fort-shevchenko
# Processing Record 41 of Set 1 | gouyave
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | codrington
# Processing Record 45 of Set 1 | tilichiki
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | severobaykalsk
# Processing Record 48 of Set 1 | vanimo
# Processing Record 49 of Set 1 | camp verde
# Processing Record 50 of Set 1 | baie-comeau
# Processing Record 1 of Set 2 | puerto penasco
# Processing Record 2 of Set 2 | marzuq
# Processing Record 3 of Set 2 | mitsamiouli
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | pontes e lacerda
# Processing Record 6 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | zyryanka
# Processing Record 9 of Set 2 | comodoro rivadavia
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | bonavista
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | barreirinha
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | vondrozo
# Processing Record 16 of Set 2 | namatanai
# Processing Record 17 of Set 2 | vao
# Processing Record 18 of Set 2 | mana
# Processing Record 19 of Set 2 | grindavik
# Processing Record 20 of Set 2 | teguise
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | ushuaia
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | dhidhdhoo
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | port macquarie
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | lodingen
# Processing Record 30 of Set 2 | biak
# Processing Record 31 of Set 2 | korla
# Processing Record 32 of Set 2 | geresk
# City not found. Skipping...
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | faridkot
# Processing Record 35 of Set 2 | lubao
# Processing Record 36 of Set 2 | porto murtinho
# Processing Record 37 of Set 2 | balabac
# Processing Record 38 of Set 2 | superior
# Processing Record 39 of Set 2 | kysyl-syr
# Processing Record 40 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 2 | kaitangata
# Processing Record 42 of Set 2 | manga
# Processing Record 43 of Set 2 | airai
# Processing Record 44 of Set 2 | port blair
# Processing Record 45 of Set 2 | adre
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | clyde river
# Processing Record 49 of Set 2 | yulara
# Processing Record 50 of Set 2 | saskylakh
# Processing Record 1 of Set 3 | sao gabriel da cachoeira
# Processing Record 2 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | kudahuvadhoo
# Processing Record 5 of Set 3 | srednekolymsk
# Processing Record 6 of Set 3 | mezen
# Processing Record 7 of Set 3 | dikson
# Processing Record 8 of Set 3 | hailar
# Processing Record 9 of Set 3 | fengzhen
# Processing Record 10 of Set 3 | saldanha
# Processing Record 11 of Set 3 | chuy
# Processing Record 12 of Set 3 | homer
# Processing Record 13 of Set 3 | mandurah
# Processing Record 14 of Set 3 | taoudenni
# Processing Record 15 of Set 3 | bulgan
# Processing Record 16 of Set 3 | champerico
# Processing Record 17 of Set 3 | jimma
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | nome
# Processing Record 20 of Set 3 | omboue
# Processing Record 21 of Set 3 | ponta do sol
# Processing Record 22 of Set 3 | cabo san lucas
# Processing Record 23 of Set 3 | vostok
# Processing Record 24 of Set 3 | caravelas
# Processing Record 25 of Set 3 | cape town
# Processing Record 26 of Set 3 | denizli
# Processing Record 27 of Set 3 | yaan
# Processing Record 28 of Set 3 | road town
# Processing Record 29 of Set 3 | pevek
# Processing Record 30 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 3 | puerto ayora
# Processing Record 32 of Set 3 | san cristobal
# Processing Record 33 of Set 3 | hobart
# Processing Record 34 of Set 3 | esperance
# Processing Record 35 of Set 3 | komsomolskiy
# Processing Record 36 of Set 3 | manzil salim
# Processing Record 37 of Set 3 | victor harbor
# Processing Record 38 of Set 3 | itarema
# Processing Record 39 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 3 | kyren
# Processing Record 41 of Set 3 | mayumba
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | college
# Processing Record 44 of Set 3 | ardakan
# Processing Record 45 of Set 3 | barrow
# Processing Record 46 of Set 3 | garoua
# Processing Record 47 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 3 | iqaluit
# Processing Record 49 of Set 3 | tiksi
# Processing Record 50 of Set 3 | beberibe
# Processing Record 1 of Set 4 | prabumulih
# Processing Record 2 of Set 4 | lebu
# Processing Record 3 of Set 4 | deputatskiy
# Processing Record 4 of Set 4 | fairbanks
# Processing Record 5 of Set 4 | grand gaube
# Processing Record 6 of Set 4 | faanui
# Processing Record 7 of Set 4 | cockburn town
# Processing Record 8 of Set 4 | gat
# Processing Record 9 of Set 4 | mahibadhoo
# Processing Record 10 of Set 4 | kodiak
# Processing Record 11 of Set 4 | salalah
# Processing Record 12 of Set 4 | bandarbeyla
# Processing Record 13 of Set 4 | posse
# Processing Record 14 of Set 4 | bethel
# Processing Record 15 of Set 4 | contamana
# Processing Record 16 of Set 4 | alofi
# Processing Record 17 of Set 4 | aksu
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | kavieng
# Processing Record 20 of Set 4 | tokur
# Processing Record 21 of Set 4 | lavrentiya
# Processing Record 22 of Set 4 | flinders
# Processing Record 23 of Set 4 | vangaindrano
# Processing Record 24 of Set 4 | ilulissat
# Processing Record 25 of Set 4 | zandak
# Processing Record 26 of Set 4 | goderich
# Processing Record 27 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 4 | aklavik
# Processing Record 29 of Set 4 | vung tau
# Processing Record 30 of Set 4 | khatanga
# Processing Record 31 of Set 4 | yanji
# Processing Record 32 of Set 4 | oromocto
# Processing Record 33 of Set 4 | lalganj
# Processing Record 34 of Set 4 | puerto escondido
# Processing Record 35 of Set 4 | north branch
# Processing Record 36 of Set 4 | kitob
# Processing Record 37 of Set 4 | nanortalik
# Processing Record 38 of Set 4 | malinyi
# Processing Record 39 of Set 4 | bad hofgastein
# Processing Record 40 of Set 4 | shingu
# Processing Record 41 of Set 4 | beian
# Processing Record 42 of Set 4 | havre-saint-pierre
# Processing Record 43 of Set 4 | poum
# Processing Record 44 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 4 | sativasur
# Processing Record 46 of Set 4 | olafsvik
# Processing Record 47 of Set 4 | pisco
# Processing Record 48 of Set 4 | new glasgow
# Processing Record 49 of Set 4 | mbaiki
# Processing Record 50 of Set 4 | nabire
# Processing Record 1 of Set 5 | casas grandes
# Processing Record 2 of Set 5 | thompson
# Processing Record 3 of Set 5 | salinas
# Processing Record 4 of Set 5 | manali
# Processing Record 5 of Set 5 | lompoc
# Processing Record 6 of Set 5 | lagoa
# Processing Record 7 of Set 5 | ixtapa
# Processing Record 8 of Set 5 | tuktoyaktuk
# Processing Record 9 of Set 5 | wanxian
# Processing Record 10 of Set 5 | cherskiy
# Processing Record 11 of Set 5 | kidal
# Processing Record 12 of Set 5 | severo-kurilsk
# Processing Record 13 of Set 5 | guerrero negro
# Processing Record 14 of Set 5 | yian
# City not found. Skipping...
# Processing Record 15 of Set 5 | coquimbo
# Processing Record 16 of Set 5 | rocha
# Processing Record 17 of Set 5 | anadyr
# Processing Record 18 of Set 5 | poroszlo
# Processing Record 19 of Set 5 | yanam
# Processing Record 20 of Set 5 | mogadishu
# Processing Record 21 of Set 5 | preobrazheniye
# Processing Record 22 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 5 | bukama
# Processing Record 24 of Set 5 | thinadhoo
# Processing Record 25 of Set 5 | saint george
# Processing Record 26 of Set 5 | walldurn
# Processing Record 27 of Set 5 | kahului
# Processing Record 28 of Set 5 | bubaque
# Processing Record 29 of Set 5 | provideniya
# Processing Record 30 of Set 5 | ancud
# Processing Record 31 of Set 5 | bay roberts
# Processing Record 32 of Set 5 | dudinka
# Processing Record 33 of Set 5 | sisimiut
# Processing Record 34 of Set 5 | liberal
# Processing Record 35 of Set 5 | baykit
# Processing Record 36 of Set 5 | klaksvik
# Processing Record 37 of Set 5 | faya
# Processing Record 38 of Set 5 | mahebourg
# Processing Record 39 of Set 5 | arraial do cabo
# Processing Record 40 of Set 5 | nelson bay
# Processing Record 41 of Set 5 | mucurapo
# Processing Record 42 of Set 5 | eureka
# Processing Record 43 of Set 5 | san andres
# Processing Record 44 of Set 5 | lensk
# Processing Record 45 of Set 5 | praia
# Processing Record 46 of Set 5 | imbituba
# Processing Record 47 of Set 5 | borda da mata
# Processing Record 48 of Set 5 | broken hill
# Processing Record 49 of Set 5 | flin flon
# Processing Record 50 of Set 5 | belawan
# Processing Record 1 of Set 6 | ziway
# Processing Record 2 of Set 6 | colac
# Processing Record 3 of Set 6 | cap malheureux
# Processing Record 4 of Set 6 | san luis
# Processing Record 5 of Set 6 | envira
# Processing Record 6 of Set 6 | iwanai
# Processing Record 7 of Set 6 | zavetnoye
# Processing Record 8 of Set 6 | waipawa
# Processing Record 9 of Set 6 | avesta
# Processing Record 10 of Set 6 | slave lake
# Processing Record 11 of Set 6 | sola
# Processing Record 12 of Set 6 | kushmurun
# Processing Record 13 of Set 6 | vestmannaeyjar
# Processing Record 14 of Set 6 | tukrah
# Processing Record 15 of Set 6 | parry sound
# Processing Record 16 of Set 6 | digby
# Processing Record 17 of Set 6 | meulaboh
# Processing Record 18 of Set 6 | jawhar
# Processing Record 19 of Set 6 | ongandjera
# Processing Record 20 of Set 6 | manono
# Processing Record 21 of Set 6 | ayr
# Processing Record 22 of Set 6 | tolaga bay
# Processing Record 23 of Set 6 | pandan
# Processing Record 24 of Set 6 | yumen
# Processing Record 25 of Set 6 | mar del plata
# Processing Record 26 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 6 | nishihara
# Processing Record 28 of Set 6 | ahipara
# Processing Record 29 of Set 6 | magdalena
# Processing Record 30 of Set 6 | keflavik
# Processing Record 31 of Set 6 | chitral
# Processing Record 32 of Set 6 | atar
# Processing Record 33 of Set 6 | rio grande
# Processing Record 34 of Set 6 | kambove
# Processing Record 35 of Set 6 | souillac
# Processing Record 36 of Set 6 | luganville
# Processing Record 37 of Set 6 | guarapari
# Processing Record 38 of Set 6 | billings
# Processing Record 39 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 6 | qandala
# Processing Record 41 of Set 6 | yar-sale
# Processing Record 42 of Set 6 | borger
# Processing Record 43 of Set 6 | horasan
# Processing Record 44 of Set 6 | geraldton
# Processing Record 45 of Set 6 | kologriv
# Processing Record 46 of Set 6 | muros
# Processing Record 47 of Set 6 | valdivia
# Processing Record 48 of Set 6 | salekhard
# Processing Record 49 of Set 6 | bagua grande
# Processing Record 50 of Set 6 | port alfred
# Processing Record 1 of Set 7 | pogranichnyy
# Processing Record 2 of Set 7 | taltal
# Processing Record 3 of Set 7 | chokurdakh
# Processing Record 4 of Set 7 | slobodskoy
# Processing Record 5 of Set 7 | daru
# Processing Record 6 of Set 7 | sungaipenuh
# Processing Record 7 of Set 7 | mandalgovi
# Processing Record 8 of Set 7 | amla
# Processing Record 9 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 7 | hamilton
# Processing Record 11 of Set 7 | kolpashevo
# Processing Record 12 of Set 7 | presidente medici
# Processing Record 13 of Set 7 | tabou
# Processing Record 14 of Set 7 | upernavik
# Processing Record 15 of Set 7 | bathsheba
# Processing Record 16 of Set 7 | sitka
# Processing Record 17 of Set 7 | ulladulla
# Processing Record 18 of Set 7 | lincoln
# Processing Record 19 of Set 7 | aborlan
# Processing Record 20 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 7 | alice springs
# Processing Record 23 of Set 7 | norman wells
# Processing Record 24 of Set 7 | san quintin
# Processing Record 25 of Set 7 | porto novo
# Processing Record 26 of Set 7 | samarai
# Processing Record 27 of Set 7 | georgetown
# Processing Record 28 of Set 7 | demerval lobao
# Processing Record 29 of Set 7 | balkanabat
# Processing Record 30 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 31 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 32 of Set 7 | kirovskiy
# Processing Record 33 of Set 7 | bambanglipuro
# Processing Record 34 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 7 | tessalit
# Processing Record 36 of Set 7 | tayu
# Processing Record 37 of Set 7 | tarnow
# Processing Record 38 of Set 7 | sinnamary
# Processing Record 39 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 40 of Set 7 | namibe
# Processing Record 41 of Set 7 | okhotsk
# Processing Record 42 of Set 7 | villa bruzual
# Processing Record 43 of Set 7 | kihei
# Processing Record 44 of Set 7 | fort nelson
# Processing Record 45 of Set 7 | sobolevo
# Processing Record 46 of Set 7 | tabas
# Processing Record 47 of Set 7 | mlonggo
# Processing Record 48 of Set 7 | danielskuil
# Processing Record 49 of Set 7 | ostrovnoy
# Processing Record 50 of Set 7 | forio
# Processing Record 1 of Set 8 | hami
# Processing Record 2 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 8 | narsaq
# Processing Record 4 of Set 8 | portland
# Processing Record 5 of Set 8 | requena
# Processing Record 6 of Set 8 | neiafu
# Processing Record 7 of Set 8 | gravdal
# Processing Record 8 of Set 8 | lujan
# Processing Record 9 of Set 8 | saint-joseph
# Processing Record 10 of Set 8 | zhangye
# Processing Record 11 of Set 8 | alexandria
# Processing Record 12 of Set 8 | mopti
# Processing Record 13 of Set 8 | dunedin
# Processing Record 14 of Set 8 | sulangan
# Processing Record 15 of Set 8 | banjar
# Processing Record 16 of Set 8 | calabozo
# Processing Record 17 of Set 8 | nhulunbuy
# Processing Record 18 of Set 8 | kutum
# Processing Record 19 of Set 8 | jammal
# Processing Record 20 of Set 8 | lorengau
# Processing Record 21 of Set 8 | mareeba
# Processing Record 22 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 8 | padang
# Processing Record 24 of Set 8 | fortuna
# Processing Record 25 of Set 8 | apiai
# Processing Record 26 of Set 8 | pocoes
# Processing Record 27 of Set 8 | nizhniy kuranakh
# Processing Record 28 of Set 8 | topchanchi
# Processing Record 29 of Set 8 | santa cruz de la palma
# Processing Record 30 of Set 8 | sabang
# Processing Record 31 of Set 8 | lata
# Processing Record 32 of Set 8 | oudtshoorn
# Processing Record 33 of Set 8 | cabedelo
# Processing Record 34 of Set 8 | furmanov
# Processing Record 35 of Set 8 | oistins
# Processing Record 36 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 37 of Set 8 | milici
# Processing Record 38 of Set 8 | longyearbyen
# Processing Record 39 of Set 8 | khomutovo
# Processing Record 40 of Set 8 | dwarka
# Processing Record 41 of Set 8 | ust-maya
# Processing Record 42 of Set 8 | skuodas
# Processing Record 43 of Set 8 | roald
# Processing Record 44 of Set 8 | kizukuri
# Processing Record 45 of Set 8 | san policarpo
# Processing Record 46 of Set 8 | grants pass
# Processing Record 47 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 8 | leh
# Processing Record 49 of Set 8 | maddur
# Processing Record 50 of Set 8 | bovolone
# Processing Record 1 of Set 9 | mount gambier
# Processing Record 2 of Set 9 | goure
# Processing Record 3 of Set 9 | yeppoon
# Processing Record 4 of Set 9 | hambantota
# Processing Record 5 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 9 | talnakh
# Processing Record 7 of Set 9 | katsuura
# Processing Record 8 of Set 9 | yurino
# Processing Record 9 of Set 9 | mombetsu
# Processing Record 10 of Set 9 | steamboat springs
# Processing Record 11 of Set 9 | nampula
# Processing Record 12 of Set 9 | northam
# Processing Record 13 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 9 | tocopilla
# Processing Record 15 of Set 9 | takoradi
# Processing Record 16 of Set 9 | iquitos
# Processing Record 17 of Set 9 | teya
# Processing Record 18 of Set 9 | salihorsk
# Processing Record 19 of Set 9 | minggang
# Processing Record 20 of Set 9 | itaituba
# Processing Record 21 of Set 9 | stornoway
# Processing Record 22 of Set 9 | trairi
# Processing Record 23 of Set 9 | sioux lookout
# Processing Record 24 of Set 9 | auki
# Processing Record 25 of Set 9 | miyazu
# Processing Record 26 of Set 9 | nola
# Processing Record 27 of Set 9 | husavik
# Processing Record 28 of Set 9 | qaqortoq
# Processing Record 29 of Set 9 | kununurra
# Processing Record 30 of Set 9 | barbastro
# Processing Record 31 of Set 9 | kamenolomni
# Processing Record 32 of Set 9 | kuala terengganu
# Processing Record 33 of Set 9 | nanzhang
# Processing Record 34 of Set 9 | coahuayana
# Processing Record 35 of Set 9 | luau
# Processing Record 36 of Set 9 | ruswil
# Processing Record 37 of Set 9 | abu kamal
# Processing Record 38 of Set 9 | sao joao da barra
# Processing Record 39 of Set 9 | koryazhma
# Processing Record 40 of Set 9 | miri
# Processing Record 41 of Set 9 | bengkulu
# Processing Record 42 of Set 9 | sinjar
# Processing Record 43 of Set 9 | ponta delgada
# Processing Record 44 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 9 | pacific grove
# Processing Record 46 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 9 | moron
# Processing Record 48 of Set 9 | lakselv
# Processing Record 49 of Set 9 | maniago
# Processing Record 50 of Set 9 | gayny
# Processing Record 1 of Set 10 | campoverde
# Processing Record 2 of Set 10 | kankaanpaa
# Processing Record 3 of Set 10 | mindelo
# Processing Record 4 of Set 10 | havelock
# Processing Record 5 of Set 10 | rumphi
# Processing Record 6 of Set 10 | maragogi
# Processing Record 7 of Set 10 | solnechnyy
# Processing Record 8 of Set 10 | adrar
# Processing Record 9 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 10 | musafirkhana
# Processing Record 11 of Set 10 | libourne
# Processing Record 12 of Set 10 | sur
# Processing Record 13 of Set 10 | kruisfontein
# Processing Record 14 of Set 10 | zakamensk
# Processing Record 15 of Set 10 | jalu
# Processing Record 16 of Set 10 | mizdah
# Processing Record 17 of Set 10 | troitskoye
# Processing Record 18 of Set 10 | raudeberg
# Processing Record 19 of Set 10 | la ronge
# Processing Record 20 of Set 10 | riyadh
# Processing Record 21 of Set 10 | san patricio
# Processing Record 22 of Set 10 | uray
# Processing Record 23 of Set 10 | hervey bay
# Processing Record 24 of Set 10 | haapiti
# Processing Record 25 of Set 10 | shizunai
# Processing Record 26 of Set 10 | xiamen
# Processing Record 27 of Set 10 | monduli
# Processing Record 28 of Set 10 | vila franca do campo
# Processing Record 29 of Set 10 | chikoy
# City not found. Skipping...
# Processing Record 30 of Set 10 | benalla
# Processing Record 31 of Set 10 | hashtrud
# Processing Record 32 of Set 10 | vardo
# Processing Record 33 of Set 10 | kieta
# Processing Record 34 of Set 10 | burnie
# Processing Record 35 of Set 10 | vrable
# Processing Record 36 of Set 10 | hayden
# Processing Record 37 of Set 10 | mount hagen
# Processing Record 38 of Set 10 | muroto
# Processing Record 39 of Set 10 | port hardy
# Processing Record 40 of Set 10 | chippenham
# Processing Record 41 of Set 10 | haines junction
# Processing Record 42 of Set 10 | tadine
# Processing Record 43 of Set 10 | hangzhou
# Processing Record 44 of Set 10 | guymon
# Processing Record 45 of Set 10 | lufilufi
# Processing Record 46 of Set 10 | maceio
# Processing Record 47 of Set 10 | bilibino
# Processing Record 48 of Set 10 | sao filipe
# Processing Record 49 of Set 10 | bambous virieux
# Processing Record 50 of Set 10 | wanning
# Processing Record 1 of Set 11 | akdepe
# Processing Record 2 of Set 11 | bulnes
# Processing Record 3 of Set 11 | bosobolo
# Processing Record 4 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 11 | nouadhibou
# Processing Record 6 of Set 11 | segarcea vale
# Processing Record 7 of Set 11 | kamyaran
# Processing Record 8 of Set 11 | savannah bight
# Processing Record 9 of Set 11 | torbay
# Processing Record 10 of Set 11 | angoche
# Processing Record 11 of Set 11 | alghero
# Processing Record 12 of Set 11 | yagodnoye
# Processing Record 13 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 14 of Set 11 | gushikawa
# Processing Record 15 of Set 11 | katangli
# Processing Record 16 of Set 11 | ous
# Processing Record 17 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 11 | bolshaya martynovka
# Processing Record 19 of Set 11 | luzhou
# Processing Record 20 of Set 11 | laguna
# Processing Record 21 of Set 11 | terrak
# Processing Record 22 of Set 11 | careiro da varzea
# Processing Record 23 of Set 11 | quatre cocos
# Processing Record 24 of Set 11 | leningradskiy
# Processing Record 25 of Set 11 | toowoomba
# Processing Record 26 of Set 11 | sorland
# Processing Record 27 of Set 11 | luderitz
# Processing Record 28 of Set 11 | waitati
# Processing Record 29 of Set 11 | pauini
# Processing Record 30 of Set 11 | port elizabeth
# Processing Record 31 of Set 11 | valparaiso
# Processing Record 32 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 33 of Set 11 | erie
# Processing Record 34 of Set 11 | boa vista
# Processing Record 35 of Set 11 | avera
# Processing Record 36 of Set 11 | umm lajj
# Processing Record 37 of Set 11 | axixa do tocantins
# City not found. Skipping...
# Processing Record 38 of Set 11 | nuevo progreso
# Processing Record 39 of Set 11 | pangnirtung
# Processing Record 40 of Set 11 | plast
# Processing Record 41 of Set 11 | kloulklubed
# Processing Record 42 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 11 | kirakira
# Processing Record 44 of Set 11 | volksrust
# Processing Record 45 of Set 11 | baboua
# City not found. Skipping...
# Processing Record 46 of Set 11 | sept-iles
# Processing Record 47 of Set 11 | kailua
# Processing Record 48 of Set 11 | ilo
# Processing Record 49 of Set 11 | north bend
# Processing Record 50 of Set 11 | bethanien
# Processing Record 1 of Set 12 | palmer
# Processing Record 2 of Set 12 | honghu
# Processing Record 3 of Set 12 | sovetskiy
# Processing Record 4 of Set 12 | yambio
# Processing Record 5 of Set 12 | lahaina
# Processing Record 6 of Set 12 | tshikapa
# Processing Record 7 of Set 12 | tagusao
# Processing Record 8 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 12 | beaverlodge
# Processing Record 10 of Set 12 | chegdomyn
# Processing Record 11 of Set 12 | ola
# Processing Record 12 of Set 12 | agadez
# Processing Record 13 of Set 12 | cidahu
# Processing Record 14 of Set 12 | stephenville
# Processing Record 15 of Set 12 | horn lake
# Processing Record 16 of Set 12 | zhengjiatun
# Processing Record 17 of Set 12 | lakes entrance
# Processing Record 18 of Set 12 | fredonia
# Processing Record 19 of Set 12 | kumluca
# Processing Record 20 of Set 12 | zaysan
# Processing Record 21 of Set 12 | miles city
# Processing Record 22 of Set 12 | sunbury
# Processing Record 23 of Set 12 | general pico
# Processing Record 24 of Set 12 | state college
# Processing Record 25 of Set 12 | tirano
# Processing Record 26 of Set 12 | olinda
# Processing Record 27 of Set 12 | bar-le-duc
# Processing Record 28 of Set 12 | port lavaca
# Processing Record 29 of Set 12 | masallatah
# Processing Record 30 of Set 12 | bowen
# Processing Record 31 of Set 12 | reguengos de monsaraz
# Processing Record 32 of Set 12 | zhezkazgan
# Processing Record 33 of Set 12 | poquoson
# Processing Record 34 of Set 12 | shimoda
# Processing Record 35 of Set 12 | porbandar
# Processing Record 36 of Set 12 | abong mbang
# Processing Record 37 of Set 12 | paamiut
# Processing Record 38 of Set 12 | aktau
# Processing Record 39 of Set 12 | tura
# Processing Record 40 of Set 12 | torbat-e jam
# Processing Record 41 of Set 12 | priiskovyy
# Processing Record 42 of Set 12 | smithers
# Processing Record 43 of Set 12 | severo-yeniseyskiy
# Processing Record 44 of Set 12 | gornopravdinsk
# Processing Record 45 of Set 12 | tuburan
# Processing Record 46 of Set 12 | fatikchhari
# City not found. Skipping...
# Processing Record 47 of Set 12 | nioro
# Processing Record 48 of Set 12 | lydenburg
# Processing Record 49 of Set 12 | tahta
# Processing Record 50 of Set 12 | siavonga
# Processing Record 1 of Set 13 | shadrinsk
# Processing Record 2 of Set 13 | sidi ali
# Processing Record 3 of Set 13 | maiduguri
# Processing Record 4 of Set 13 | beringovskiy
# Processing Record 5 of Set 13 | resistencia
# Processing Record 6 of Set 13 | clinton
# Processing Record 7 of Set 13 | dormidontovka
# Processing Record 8 of Set 13 | bumba
# Processing Record 9 of Set 13 | westport
# Processing Record 10 of Set 13 | katobu
# Processing Record 11 of Set 13 | pringsewu
# Processing Record 12 of Set 13 | weiser
# Processing Record 13 of Set 13 | cabra
# Processing Record 14 of Set 13 | kamenka
# Processing Record 15 of Set 13 | corrientes
# Processing Record 16 of Set 13 | el tigre
# Processing Record 17 of Set 13 | aketi
# Processing Record 18 of Set 13 | bud
# Processing Record 19 of Set 13 | lethem
# Processing Record 20 of Set 13 | tambura
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 576

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City    Lat     Lng  Max Temp Current Description  \
# 0               Natchez  31.56  -91.40     89.60           clear sky
# 1          Richards Bay -28.78   32.04     61.41           clear sky
# 2               Mataura -46.19  168.86     39.00     overcast clouds
# 3                 Seoul  37.57  126.98     69.80           clear sky
# 4              Berlevag  70.86   29.09     42.80     overcast clouds
# 5         Novyy Urengoy  66.08   76.63     40.24          few clouds
# 6  Guia Lopes Da Laguna -21.46  -56.11     85.53          few clouds
# 7                Kupang -10.17  123.58     76.64          few clouds
# 8              Tasiilaq  65.61  -37.64     41.00             drizzle
# 9                  Gizo  -8.10  156.84     81.97          light rain
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0           0.00           0.00        43           1        4.70      US
# 1           0.00           0.00        88           0        4.70      ZA
# 2           0.00           0.00        83         100        3.00      NZ
# 3           0.00           0.00        93           0        1.12      KR
# 4           0.00           0.00        75          90       12.75      NO
# 5           0.00           0.00        71          11        6.60      RU
# 6           0.00           0.00        47          12        5.61      BR
# 7           0.00           0.00        80          11       14.09      ID
# 8           0.00           0.00        93          75        3.36      GL
# 9           0.38           0.38        76          22        6.15      SB

# %%
# Re arragne DataFrame labels
new_column_order=["City", "Country", "Lat", "Lng", "Current Description", "Rain (inches)", "Snow (inches)", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df=city_data_df[new_column_order]
city_data_df
# Out:
#              City Country    Lat     Lng Current Description  Rain (inches)  \
# 0         Natchez      US  31.56  -91.40           clear sky           0.00
# 1    Richards Bay      ZA -28.78   32.04           clear sky           0.00
# 2         Mataura      NZ -46.19  168.86     overcast clouds           0.00
# 3           Seoul      KR  37.57  126.98           clear sky           0.00
# 4        Berlevag      NO  70.86   29.09     overcast clouds           0.00
# ..            ...     ...    ...     ...                 ...            ...
# 571      El Tigre      VE   8.89  -64.25    scattered clouds           0.00
# 572         Aketi      CD   2.74   23.78     overcast clouds           0.00
# 573           Bud      US  39.45  -86.18    scattered clouds           0.00
# 574        Lethem      GY   3.38  -59.80       moderate rain           1.49
# 575       Tambura      SS   5.60   27.47       broken clouds           0.00
#
#      Snow (inches)  Max Temp  Humidity  Cloudiness  Wind Speed
# 0             0.00     89.60        43           1        4.70
# 1             0.00     61.41        88           0        4.70
# 2             0.00     39.00        83         100        3.00
# 3             0.00     69.80        93           0        1.12
# 4             0.00     42.80        75          90       12.75
# ..             ...       ...       ...         ...         ...
# 571           0.00     86.61        57          49       10.25
# 572           0.00     73.67        80         100        1.70
# 573           0.00     88.00        35          40        6.71
# 574           1.49     82.67        79         100        0.67
# 575           0.00     68.88        94          74        2.64
#
# [576 rows x 11 columns]

# %%
raining_cities=city_data_df.loc[city_data_df["Rain (inches)"]>0]
raining_cities
# Out:
#               City Country    Lat     Lng Current Description  Rain (inches)  \
# 9             Gizo      SB  -8.10  156.84          light rain           0.38
# 19         Chimore      BO -16.98  -65.13          light rain           0.29
# 26    Chapulhuacan      MX  21.17  -98.90          light rain           0.16
# 32       Hithadhoo      MV  -0.60   73.08          light rain           0.29
# 35         Rikitea      PF -23.12 -134.97       moderate rain           1.34
# ..             ...     ...    ...     ...                 ...            ...
# 501       Kirakira      SB -10.45  161.92          light rain           0.31
# 530  State College      US  40.79  -77.86       moderate rain           1.78
# 545           Tura      IN  25.52   90.22       moderate rain           2.78
# 552          Nioro      GM  13.35  -15.75          light rain           0.25
# 574         Lethem      GY   3.38  -59.80       moderate rain           1.49
#
#      Snow (inches)  Max Temp  Humidity  Cloudiness  Wind Speed
# 9             0.38     81.97        76          22        6.15
# 19            0.29     78.40        85         100        1.90
# 26            0.16     81.30        63          12        7.87
# 32            0.29     84.02        72         100        6.29
# 35            1.34     73.36        86         100       21.41
# ..             ...       ...       ...         ...         ...
# 501           0.31     80.24        81          28        7.76
# 530           1.78     78.01        69          75        4.70
# 545           2.78     74.57        97         100        5.79
# 552           0.25     84.76        67          45       10.38
# 574           1.49     82.67        79         100        0.67
#
# [64 rows x 11 columns]

# %%
snowing_cities=city_data_df.loc[city_data_df["Snow (inches)"]>0]
snowing_cities
# Out:
#               City Country    Lat     Lng Current Description  Rain (inches)  \
# 9             Gizo      SB  -8.10  156.84          light rain           0.38
# 19         Chimore      BO -16.98  -65.13          light rain           0.29
# 26    Chapulhuacan      MX  21.17  -98.90          light rain           0.16
# 32       Hithadhoo      MV  -0.60   73.08          light rain           0.29
# 35         Rikitea      PF -23.12 -134.97       moderate rain           1.34
# ..             ...     ...    ...     ...                 ...            ...
# 501       Kirakira      SB -10.45  161.92          light rain           0.31
# 530  State College      US  40.79  -77.86       moderate rain           1.78
# 545           Tura      IN  25.52   90.22       moderate rain           2.78
# 552          Nioro      GM  13.35  -15.75          light rain           0.25
# 574         Lethem      GY   3.38  -59.80       moderate rain           1.49
#
#      Snow (inches)  Max Temp  Humidity  Cloudiness  Wind Speed
# 9             0.38     81.97        76          22        6.15
# 19            0.29     78.40        85         100        1.90
# 26            0.16     81.30        63          12        7.87
# 32            0.29     84.02        72         100        6.29
# 35            1.34     73.36        86         100       21.41
# ..             ...       ...       ...         ...         ...
# 501           0.31     80.24        81          28        7.76
# 530           1.78     78.01        69          75        4.70
# 545           2.78     74.57        97         100        5.79
# 552           0.25     84.76        67          45       10.38
# 574           1.49     82.67        79         100        0.67
#
# [64 rows x 11 columns]

# %%
# Create the output file (CSV).
output_data_file = "data/Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
