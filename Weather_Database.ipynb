# %% [markdown]
# # Challenge: Part 1- Get the weather description and amount of precipication for each city

# %%
# Import the dependencies.
from citipy import citipy
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 613

# %%
# Import the request library
import requests
from datetime import datetime
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-" * 25)

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for index, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data: max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
        try:
            city_rain_inches=city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches=0
        try:
            city_snow_inches=city_weather["rain"]["1h"]
        except KeyError:
            city_snow_inches=0
            
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-" * 20)
print("Data Retrieval Complete      ")
print("-" * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | young
# Processing Record 2 of Set 1 | berlevag
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | nauta
# Processing Record 7 of Set 1 | zhigansk
# Processing Record 8 of Set 1 | sao raimundo das mangabeiras
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | hirado
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 13 of Set 1 | lisse
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | naze
# Processing Record 17 of Set 1 | portland
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | gelnhausen
# Processing Record 22 of Set 1 | chunskiy
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | nizhnevartovsk
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | san patricio
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | eyemouth
# Processing Record 33 of Set 1 | sorland
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | biak
# Processing Record 36 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | praya
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | ancud
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | entre rios
# Processing Record 44 of Set 1 | north platte
# Processing Record 45 of Set 1 | bani
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | lleida
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | asau
# Processing Record 50 of Set 1 | nanortalik
# Processing Record 1 of Set 2 | anadyr
# Processing Record 2 of Set 2 | sobolevo
# Processing Record 3 of Set 2 | hobyo
# Processing Record 4 of Set 2 | susanino
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | mirpur sakro
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | port blair
# Processing Record 9 of Set 2 | guerrero negro
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | luderitz
# Processing Record 12 of Set 2 | dharchula
# Processing Record 13 of Set 2 | beringovskiy
# Processing Record 14 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 2 | country club
# Processing Record 17 of Set 2 | kilindoni
# Processing Record 18 of Set 2 | dom pedrito
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | mattru
# Processing Record 25 of Set 2 | lokosovo
# Processing Record 26 of Set 2 | kruisfontein
# Processing Record 27 of Set 2 | ojuelos de jalisco
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | aklavik
# Processing Record 30 of Set 2 | yasothon
# Processing Record 31 of Set 2 | mount isa
# Processing Record 32 of Set 2 | olafsvik
# Processing Record 33 of Set 2 | salinopolis
# Processing Record 34 of Set 2 | penapolis
# Processing Record 35 of Set 2 | mar del plata
# Processing Record 36 of Set 2 | clyde river
# Processing Record 37 of Set 2 | lata
# Processing Record 38 of Set 2 | hofn
# Processing Record 39 of Set 2 | viedma
# Processing Record 40 of Set 2 | sao jose da coroa grande
# Processing Record 41 of Set 2 | bubaque
# Processing Record 42 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 2 | namatanai
# Processing Record 44 of Set 2 | karratha
# Processing Record 45 of Set 2 | deh rawud
# City not found. Skipping...
# Processing Record 46 of Set 2 | mweka
# Processing Record 47 of Set 2 | dunedin
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | mujiayingzi
# Processing Record 50 of Set 2 | muzhi
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 3 | kaitangata
# Processing Record 4 of Set 3 | phibun mangsahan
# Processing Record 5 of Set 3 | kavieng
# Processing Record 6 of Set 3 | ponta do sol
# Processing Record 7 of Set 3 | constitucion
# Processing Record 8 of Set 3 | jatibonico
# Processing Record 9 of Set 3 | hami
# Processing Record 10 of Set 3 | makakilo city
# Processing Record 11 of Set 3 | narsaq
# Processing Record 12 of Set 3 | airai
# Processing Record 13 of Set 3 | kondinskoye
# Processing Record 14 of Set 3 | yulara
# Processing Record 15 of Set 3 | vakhrushev
# Processing Record 16 of Set 3 | sadiqabad
# Processing Record 17 of Set 3 | champasak
# Processing Record 18 of Set 3 | omboue
# Processing Record 19 of Set 3 | new norfolk
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | san quintin
# Processing Record 22 of Set 3 | fortuna
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | paamiut
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | los andes
# Processing Record 28 of Set 3 | pierre
# Processing Record 29 of Set 3 | sola
# Processing Record 30 of Set 3 | east london
# Processing Record 31 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 3 | arlit
# Processing Record 33 of Set 3 | garowe
# Processing Record 34 of Set 3 | ha tinh
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | faanui
# Processing Record 37 of Set 3 | hovd
# Processing Record 38 of Set 3 | aksu
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | ulladulla
# Processing Record 41 of Set 3 | vila franca do campo
# Processing Record 42 of Set 3 | athabasca
# Processing Record 43 of Set 3 | sibu
# Processing Record 44 of Set 3 | haines junction
# Processing Record 45 of Set 3 | alyangula
# Processing Record 46 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 3 | okakarara
# Processing Record 48 of Set 3 | bogotol
# Processing Record 49 of Set 3 | umm lajj
# Processing Record 50 of Set 3 | sao filipe
# Processing Record 1 of Set 4 | cairns
# Processing Record 2 of Set 4 | severo-kurilsk
# Processing Record 3 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 4 | kracheh
# City not found. Skipping...
# Processing Record 5 of Set 4 | marsh harbour
# Processing Record 6 of Set 4 | ji-parana
# City not found. Skipping...
# Processing Record 7 of Set 4 | fare
# Processing Record 8 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 4 | katobu
# Processing Record 10 of Set 4 | le port
# Processing Record 11 of Set 4 | tougue
# Processing Record 12 of Set 4 | costinesti
# Processing Record 13 of Set 4 | mbinga
# Processing Record 14 of Set 4 | port macquarie
# Processing Record 15 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 16 of Set 4 | boa vista
# Processing Record 17 of Set 4 | touros
# Processing Record 18 of Set 4 | vardo
# Processing Record 19 of Set 4 | jimma
# Processing Record 20 of Set 4 | glenwood springs
# Processing Record 21 of Set 4 | otterup
# Processing Record 22 of Set 4 | ketchikan
# Processing Record 23 of Set 4 | ust-tsilma
# Processing Record 24 of Set 4 | znamenskoye
# Processing Record 25 of Set 4 | aporawan
# City not found. Skipping...
# Processing Record 26 of Set 4 | souillac
# Processing Record 27 of Set 4 | ribeira grande
# Processing Record 28 of Set 4 | port lincoln
# Processing Record 29 of Set 4 | chokurdakh
# Processing Record 30 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 4 | adrar
# Processing Record 32 of Set 4 | grindavik
# Processing Record 33 of Set 4 | mandera
# Processing Record 34 of Set 4 | parrita
# Processing Record 35 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 4 | tiksi
# Processing Record 37 of Set 4 | fairbanks
# Processing Record 38 of Set 4 | veraval
# Processing Record 39 of Set 4 | vila
# Processing Record 40 of Set 4 | nantucket
# Processing Record 41 of Set 4 | avarua
# Processing Record 42 of Set 4 | suzhou
# Processing Record 43 of Set 4 | pangai
# Processing Record 44 of Set 4 | san jose de guanipa
# Processing Record 45 of Set 4 | lorengau
# Processing Record 46 of Set 4 | kadoma
# Processing Record 47 of Set 4 | hyeres
# Processing Record 48 of Set 4 | pevek
# Processing Record 49 of Set 4 | turukhansk
# Processing Record 50 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 5 | bugiri
# Processing Record 2 of Set 5 | mount gambier
# Processing Record 3 of Set 5 | cherskiy
# Processing Record 4 of Set 5 | kahului
# Processing Record 5 of Set 5 | prienai
# Processing Record 6 of Set 5 | carnarvon
# Processing Record 7 of Set 5 | carthage
# Processing Record 8 of Set 5 | susanville
# Processing Record 9 of Set 5 | majene
# Processing Record 10 of Set 5 | pontianak
# Processing Record 11 of Set 5 | hasaki
# Processing Record 12 of Set 5 | victoria
# Processing Record 13 of Set 5 | mamit
# Processing Record 14 of Set 5 | wawa
# Processing Record 15 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 16 of Set 5 | bathsheba
# Processing Record 17 of Set 5 | goderich
# Processing Record 18 of Set 5 | songling
# Processing Record 19 of Set 5 | katsuura
# Processing Record 20 of Set 5 | yeletskiy
# City not found. Skipping...
# Processing Record 21 of Set 5 | tabou
# Processing Record 22 of Set 5 | sanchor
# Processing Record 23 of Set 5 | paita
# Processing Record 24 of Set 5 | bay roberts
# Processing Record 25 of Set 5 | tabas
# Processing Record 26 of Set 5 | troitsko-pechorsk
# Processing Record 27 of Set 5 | udachnyy
# Processing Record 28 of Set 5 | hualmay
# Processing Record 29 of Set 5 | hokitika
# Processing Record 30 of Set 5 | plettenberg bay
# Processing Record 31 of Set 5 | manta
# Processing Record 32 of Set 5 | lebu
# Processing Record 33 of Set 5 | hithadhoo
# Processing Record 34 of Set 5 | yar-sale
# Processing Record 35 of Set 5 | dikson
# Processing Record 36 of Set 5 | leh
# Processing Record 37 of Set 5 | henties bay
# Processing Record 38 of Set 5 | sioux lookout
# Processing Record 39 of Set 5 | bonavista
# Processing Record 40 of Set 5 | cam ranh
# Processing Record 41 of Set 5 | den helder
# Processing Record 42 of Set 5 | bereznik
# Processing Record 43 of Set 5 | tuatapere
# Processing Record 44 of Set 5 | vyartsilya
# Processing Record 45 of Set 5 | pudozh
# Processing Record 46 of Set 5 | qaqortoq
# Processing Record 47 of Set 5 | sept-iles
# Processing Record 48 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 5 | mwanza
# Processing Record 50 of Set 5 | trairi
# Processing Record 1 of Set 6 | altamira
# Processing Record 2 of Set 6 | ostersund
# Processing Record 3 of Set 6 | clarksville
# Processing Record 4 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 5 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 6 | monrovia
# Processing Record 8 of Set 6 | palasa
# Processing Record 9 of Set 6 | castro
# Processing Record 10 of Set 6 | boffa
# Processing Record 11 of Set 6 | santa rosa
# Processing Record 12 of Set 6 | asha
# Processing Record 13 of Set 6 | ailigandi
# Processing Record 14 of Set 6 | miandrivazo
# Processing Record 15 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 6 | hervey bay
# Processing Record 17 of Set 6 | jiayuguan
# Processing Record 18 of Set 6 | tanshui
# City not found. Skipping...
# Processing Record 19 of Set 6 | labuhan
# Processing Record 20 of Set 6 | ajaccio
# Processing Record 21 of Set 6 | los llanos de aridane
# Processing Record 22 of Set 6 | evensk
# Processing Record 23 of Set 6 | ostashkov
# Processing Record 24 of Set 6 | kungurtug
# Processing Record 25 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 6 | langsa
# Processing Record 27 of Set 6 | itarema
# Processing Record 28 of Set 6 | sao joao da barra
# Processing Record 29 of Set 6 | shingu
# Processing Record 30 of Set 6 | ostrovnoy
# Processing Record 31 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 32 of Set 6 | mananjary
# Processing Record 33 of Set 6 | mapiri
# Processing Record 34 of Set 6 | adre
# Processing Record 35 of Set 6 | tilichiki
# Processing Record 36 of Set 6 | san rafael
# Processing Record 37 of Set 6 | buraydah
# Processing Record 38 of Set 6 | rosarito
# Processing Record 39 of Set 6 | lompoc
# Processing Record 40 of Set 6 | ati
# Processing Record 41 of Set 6 | kichmengskiy gorodok
# Processing Record 42 of Set 6 | bulgan
# Processing Record 43 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 44 of Set 6 | klaksvik
# Processing Record 45 of Set 6 | catende
# Processing Record 46 of Set 6 | mankono
# Processing Record 47 of Set 6 | talnakh
# Processing Record 48 of Set 6 | san rafael del sur
# Processing Record 49 of Set 6 | lerik
# Processing Record 50 of Set 6 | dingle
# Processing Record 1 of Set 7 | khandyga
# Processing Record 2 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 7 | harper
# Processing Record 4 of Set 7 | ambilobe
# Processing Record 5 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 7 | sanary-sur-mer
# Processing Record 7 of Set 7 | mezen
# Processing Record 8 of Set 7 | elban
# Processing Record 9 of Set 7 | kathu
# Processing Record 10 of Set 7 | meulaboh
# Processing Record 11 of Set 7 | la ronge
# Processing Record 12 of Set 7 | portobelo
# Processing Record 13 of Set 7 | joshimath
# Processing Record 14 of Set 7 | cayenne
# Processing Record 15 of Set 7 | bereda
# Processing Record 16 of Set 7 | puerto pinasco
# City not found. Skipping...
# Processing Record 17 of Set 7 | robore
# Processing Record 18 of Set 7 | marawi
# Processing Record 19 of Set 7 | codrington
# Processing Record 20 of Set 7 | tual
# Processing Record 21 of Set 7 | lavrentiya
# Processing Record 22 of Set 7 | buon me thuot
# City not found. Skipping...
# Processing Record 23 of Set 7 | hilton head island
# Processing Record 24 of Set 7 | kiunga
# Processing Record 25 of Set 7 | aktash
# Processing Record 26 of Set 7 | kieta
# Processing Record 27 of Set 7 | raton
# Processing Record 28 of Set 7 | negombo
# Processing Record 29 of Set 7 | divnomorskoye
# Processing Record 30 of Set 7 | mana
# Processing Record 31 of Set 7 | puerto madero
# Processing Record 32 of Set 7 | alice springs
# Processing Record 33 of Set 7 | dudinka
# Processing Record 34 of Set 7 | makambako
# Processing Record 35 of Set 7 | road town
# Processing Record 36 of Set 7 | temir
# Processing Record 37 of Set 7 | svetlogorsk
# Processing Record 38 of Set 7 | along
# Processing Record 39 of Set 7 | xining
# Processing Record 40 of Set 7 | rio gallegos
# Processing Record 41 of Set 7 | grand gaube
# Processing Record 42 of Set 7 | lasa
# Processing Record 43 of Set 7 | ust-uda
# Processing Record 44 of Set 7 | savannakhet
# Processing Record 45 of Set 7 | clonakilty
# Processing Record 46 of Set 7 | tulu bolo
# Processing Record 47 of Set 7 | kaoma
# Processing Record 48 of Set 7 | kamaishi
# Processing Record 49 of Set 7 | gilgit
# Processing Record 50 of Set 7 | synya
# Processing Record 1 of Set 8 | kautokeino
# Processing Record 2 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 8 | kumbo
# Processing Record 4 of Set 8 | inhambane
# Processing Record 5 of Set 8 | erie
# Processing Record 6 of Set 8 | bethel
# Processing Record 7 of Set 8 | ayia marina
# Processing Record 8 of Set 8 | zaysan
# Processing Record 9 of Set 8 | praia da vitoria
# Processing Record 10 of Set 8 | luau
# Processing Record 11 of Set 8 | ixtapa
# Processing Record 12 of Set 8 | tasiilaq
# Processing Record 13 of Set 8 | rafraf
# Processing Record 14 of Set 8 | tiznit
# Processing Record 15 of Set 8 | nhlangano
# Processing Record 16 of Set 8 | bardiyah
# Processing Record 17 of Set 8 | saint george
# Processing Record 18 of Set 8 | hambantota
# Processing Record 19 of Set 8 | half moon bay
# Processing Record 20 of Set 8 | havre-saint-pierre
# Processing Record 21 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 8 | chapais
# Processing Record 23 of Set 8 | turkmenabat
# Processing Record 24 of Set 8 | necochea
# Processing Record 25 of Set 8 | escanaba
# Processing Record 26 of Set 8 | narok
# Processing Record 27 of Set 8 | lagoa
# Processing Record 28 of Set 8 | nome
# Processing Record 29 of Set 8 | bairiki
# Processing Record 30 of Set 8 | nouadhibou
# Processing Record 31 of Set 8 | canitas
# City not found. Skipping...
# Processing Record 32 of Set 8 | norman wells
# Processing Record 33 of Set 8 | svetlyy
# Processing Record 34 of Set 8 | pareora
# Processing Record 35 of Set 8 | cap malheureux
# Processing Record 36 of Set 8 | geraldton
# Processing Record 37 of Set 8 | maniitsoq
# Processing Record 38 of Set 8 | jumla
# Processing Record 39 of Set 8 | lerwick
# Processing Record 40 of Set 8 | banka
# Processing Record 41 of Set 8 | ilulissat
# Processing Record 42 of Set 8 | bengkulu
# Processing Record 43 of Set 8 | mayo
# Processing Record 44 of Set 8 | barbastro
# Processing Record 45 of Set 8 | coolum beach
# Processing Record 46 of Set 8 | serafimovich
# Processing Record 47 of Set 8 | nemuro
# Processing Record 48 of Set 8 | russell
# Processing Record 49 of Set 8 | port augusta
# Processing Record 50 of Set 8 | port hardy
# Processing Record 1 of Set 9 | brae
# Processing Record 2 of Set 9 | baoding
# Processing Record 3 of Set 9 | kapit
# Processing Record 4 of Set 9 | taicheng
# Processing Record 5 of Set 9 | chipinge
# Processing Record 6 of Set 9 | harqalah
# Processing Record 7 of Set 9 | pisco
# Processing Record 8 of Set 9 | talcahuano
# Processing Record 9 of Set 9 | valdivia
# Processing Record 10 of Set 9 | erzin
# Processing Record 11 of Set 9 | tautira
# Processing Record 12 of Set 9 | hamilton
# Processing Record 13 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 14 of Set 9 | salinas
# Processing Record 15 of Set 9 | tadine
# Processing Record 16 of Set 9 | villa carlos paz
# Processing Record 17 of Set 9 | vao
# Processing Record 18 of Set 9 | akyab
# Processing Record 19 of Set 9 | atambua
# Processing Record 20 of Set 9 | nuuk
# Processing Record 21 of Set 9 | puri
# Processing Record 22 of Set 9 | riga
# Processing Record 23 of Set 9 | tavda
# Processing Record 24 of Set 9 | almunecar
# Processing Record 25 of Set 9 | linchuan
# City not found. Skipping...
# Processing Record 26 of Set 9 | margate
# Processing Record 27 of Set 9 | camacha
# Processing Record 28 of Set 9 | avera
# Processing Record 29 of Set 9 | qui nhon
# Processing Record 30 of Set 9 | saldanha
# Processing Record 31 of Set 9 | lincoln
# Processing Record 32 of Set 9 | krasnyy chikoy
# Processing Record 33 of Set 9 | maceio
# Processing Record 34 of Set 9 | bandar-e lengeh
# Processing Record 35 of Set 9 | novobelokatay
# Processing Record 36 of Set 9 | jaleswar
# Processing Record 37 of Set 9 | kendari
# Processing Record 38 of Set 9 | tigil
# Processing Record 39 of Set 9 | rio grande
# Processing Record 40 of Set 9 | belaya gora
# Processing Record 41 of Set 9 | matehuala
# Processing Record 42 of Set 9 | huambo
# Processing Record 43 of Set 9 | saint anthony
# Processing Record 44 of Set 9 | guasdualito
# Processing Record 45 of Set 9 | umm ruwabah
# City not found. Skipping...
# Processing Record 46 of Set 9 | saint-georges
# Processing Record 47 of Set 9 | broome
# Processing Record 48 of Set 9 | kununurra
# Processing Record 49 of Set 9 | tezu
# Processing Record 50 of Set 9 | angoram
# Processing Record 1 of Set 10 | alofi
# Processing Record 2 of Set 10 | nazas
# Processing Record 3 of Set 10 | poum
# Processing Record 4 of Set 10 | malanje
# Processing Record 5 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 10 | iquitos
# Processing Record 7 of Set 10 | sharjah
# Processing Record 8 of Set 10 | isiro
# Processing Record 9 of Set 10 | pyshma
# Processing Record 10 of Set 10 | port-gentil
# Processing Record 11 of Set 10 | dunmore town
# Processing Record 12 of Set 10 | maltahohe
# Processing Record 13 of Set 10 | novo horizonte
# Processing Record 14 of Set 10 | berikulskiy
# City not found. Skipping...
# Processing Record 15 of Set 10 | koungou
# Processing Record 16 of Set 10 | uhlove
# Processing Record 17 of Set 10 | champaign
# Processing Record 18 of Set 10 | solana beach
# Processing Record 19 of Set 10 | redmond
# Processing Record 20 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 10 | moose factory
# Processing Record 22 of Set 10 | bagrami
# Processing Record 23 of Set 10 | ahipara
# Processing Record 24 of Set 10 | lichinga
# Processing Record 25 of Set 10 | sayula
# Processing Record 26 of Set 10 | saint-joseph
# Processing Record 27 of Set 10 | bambanglipuro
# Processing Record 28 of Set 10 | deputatskiy
# Processing Record 29 of Set 10 | merauke
# Processing Record 30 of Set 10 | coihaique
# Processing Record 31 of Set 10 | garden city
# Processing Record 32 of Set 10 | srednekolymsk
# Processing Record 33 of Set 10 | havoysund
# Processing Record 34 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 10 | provideniya
# Processing Record 36 of Set 10 | manzhouli
# Processing Record 37 of Set 10 | abashiri
# Processing Record 38 of Set 10 | yerbogachen
# Processing Record 39 of Set 10 | smithers
# Processing Record 40 of Set 10 | coahuayana
# Processing Record 41 of Set 10 | vestmannaeyjar
# Processing Record 42 of Set 10 | zhob
# Processing Record 43 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 44 of Set 10 | pontal do parana
# Processing Record 45 of Set 10 | rawson
# Processing Record 46 of Set 10 | guadalupe y calvo
# Processing Record 47 of Set 10 | dargaville
# Processing Record 48 of Set 10 | mingoyo
# Processing Record 49 of Set 10 | bandarbeyla
# Processing Record 50 of Set 10 | sevlievo
# Processing Record 1 of Set 11 | itoman
# Processing Record 2 of Set 11 | secovce
# Processing Record 3 of Set 11 | cabo san lucas
# Processing Record 4 of Set 11 | kidal
# Processing Record 5 of Set 11 | sangar
# Processing Record 6 of Set 11 | sinjar
# Processing Record 7 of Set 11 | soyo
# Processing Record 8 of Set 11 | chiredzi
# Processing Record 9 of Set 11 | puerto carreno
# Processing Record 10 of Set 11 | ucluelet
# Processing Record 11 of Set 11 | asosa
# Processing Record 12 of Set 11 | opuwo
# Processing Record 13 of Set 11 | pospelikha
# Processing Record 14 of Set 11 | iqaluit
# Processing Record 15 of Set 11 | bac lieu
# Processing Record 16 of Set 11 | patti
# Processing Record 17 of Set 11 | acari
# Processing Record 18 of Set 11 | ossora
# Processing Record 19 of Set 11 | pangnirtung
# Processing Record 20 of Set 11 | cabra
# Processing Record 21 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 22 of Set 11 | indi
# Processing Record 23 of Set 11 | kashi
# Processing Record 24 of Set 11 | muli
# Processing Record 25 of Set 11 | ganzhou
# Processing Record 26 of Set 11 | itaituba
# Processing Record 27 of Set 11 | sayyan
# Processing Record 28 of Set 11 | khilok
# Processing Record 29 of Set 11 | kargasok
# Processing Record 30 of Set 11 | komsomolskiy
# Processing Record 31 of Set 11 | sevojno
# Processing Record 32 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 33 of Set 11 | valparaiso
# Processing Record 34 of Set 11 | dangara
# Processing Record 35 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 36 of Set 11 | lebyazhye
# Processing Record 37 of Set 11 | natchez
# Processing Record 38 of Set 11 | maine-soroa
# Processing Record 39 of Set 11 | kamarion
# Processing Record 40 of Set 11 | flinders
# Processing Record 41 of Set 11 | bud
# Processing Record 42 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 43 of Set 11 | san carlos de bariloche
# Processing Record 44 of Set 11 | roald
# Processing Record 45 of Set 11 | esperance
# Processing Record 46 of Set 11 | gondanglegi
# Processing Record 47 of Set 11 | champerico
# Processing Record 48 of Set 11 | oktyabrskoye
# Processing Record 49 of Set 11 | tonj
# Processing Record 50 of Set 11 | san martin
# Processing Record 1 of Set 12 | rorvik
# Processing Record 2 of Set 12 | aksarka
# Processing Record 3 of Set 12 | wollongong
# Processing Record 4 of Set 12 | muros
# Processing Record 5 of Set 12 | waipawa
# Processing Record 6 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 7 of Set 12 | gamba
# Processing Record 8 of Set 12 | parsabad
# Processing Record 9 of Set 12 | bichura
# Processing Record 10 of Set 12 | kirakira
# Processing Record 11 of Set 12 | gat
# Processing Record 12 of Set 12 | sovetskiy
# Processing Record 13 of Set 12 | platanos
# Processing Record 14 of Set 12 | broken hill
# Processing Record 15 of Set 12 | atherton
# Processing Record 16 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 12 | okha
# Processing Record 18 of Set 12 | santa maria da vitoria
# Processing Record 19 of Set 12 | marystown
# Processing Record 20 of Set 12 | potosi
# Processing Record 21 of Set 12 | palmer
# Processing Record 22 of Set 12 | la peca
# Processing Record 23 of Set 12 | kenai
# Processing Record 24 of Set 12 | coihueco
# Processing Record 25 of Set 12 | kolaras
# Processing Record 26 of Set 12 | riachao do dantas
# Processing Record 27 of Set 12 | vaitape
# Processing Record 28 of Set 12 | slave lake
# Processing Record 29 of Set 12 | moncton
# Processing Record 30 of Set 12 | raudeberg
# Processing Record 31 of Set 12 | maragogi
# Processing Record 32 of Set 12 | naustdal
# Processing Record 33 of Set 12 | gizo
# Processing Record 34 of Set 12 | panama city
# Processing Record 35 of Set 12 | sur
# Processing Record 36 of Set 12 | georgetown
# Processing Record 37 of Set 12 | sweetwater
# Processing Record 38 of Set 12 | tubuala
# Processing Record 39 of Set 12 | new port richey
# Processing Record 40 of Set 12 | marsaxlokk
# Processing Record 41 of Set 12 | sterling
# Processing Record 42 of Set 12 | te anau
# Processing Record 43 of Set 12 | tulun
# Processing Record 44 of Set 12 | longyan
# Processing Record 45 of Set 12 | halifax
# Processing Record 46 of Set 12 | chartres
# Processing Record 47 of Set 12 | marrakesh
# Processing Record 48 of Set 12 | banda aceh
# Processing Record 49 of Set 12 | tramore
# Processing Record 50 of Set 12 | kristiansund
# Processing Record 1 of Set 13 | januaria
# Processing Record 2 of Set 13 | kaliua
# Processing Record 3 of Set 13 | wuan
# Processing Record 4 of Set 13 | parintins
# Processing Record 5 of Set 13 | okhotsk
# Processing Record 6 of Set 13 | narrabri
# Processing Record 7 of Set 13 | abu dhabi
# Processing Record 8 of Set 13 | portree
# Processing Record 9 of Set 13 | strezhevoy
# Processing Record 10 of Set 13 | artyom
# Processing Record 11 of Set 13 | kirkwood
# Processing Record 12 of Set 13 | astoria
# Processing Record 13 of Set 13 | cheuskiny
# City not found. Skipping...
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 559

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                            City    Lat     Lng  Max Temp Current Description  \
# 0                         Young -32.68  -57.63     53.22       broken clouds
# 1                      Berlevag  70.86   29.09     42.39     overcast clouds
# 2                  Puerto Ayora  -0.74  -90.35     77.00       broken clouds
# 3                  Punta Arenas -53.15  -70.92     35.60       broken clouds
# 4                        Albany  42.60  -73.97     87.01          light rain
# 5                         Nauta  -4.51  -73.58     77.56          light rain
# 6                      Zhigansk  66.77  123.37     71.35          few clouds
# 7  Sao Raimundo Das Mangabeiras  -7.02  -45.48     78.89       broken clouds
# 8                        Hobart -42.88  147.33     42.01          light rain
# 9                        Hirado  33.36  129.55     71.01       broken clouds
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0           0.00           0.00        94          77        3.83      UY
# 1           0.00           0.00        79          98       18.57      NO
# 2           0.00           0.00        69          75       20.80      EC
# 3           0.00           0.00        93          75       11.41      CL
# 4           0.11           0.11        53          71        1.01      US
# 5           0.80           0.80        85          81        4.12      PE
# 6           0.00           0.00        40          12        2.06      RU
# 7           0.00           0.00        60          53        3.42      BR
# 8           0.25           0.25        93          40        1.59      AU
# 9           0.00           0.00        77          75       16.11      JP

# %%
# Re arragne DataFrame labels
new_column_order=["City", "Country", "Lat", "Lng", "Current Description", "Rain (inches)", "Snow (inches)", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df=city_data_df[new_column_order]
city_data_df
# Out:
#              City Country    Lat     Lng           Current Description  \
# 0           Young      UY -32.68  -57.63                 broken clouds
# 1        Berlevag      NO  70.86   29.09               overcast clouds
# 2    Puerto Ayora      EC  -0.74  -90.35                 broken clouds
# 3    Punta Arenas      CL -53.15  -70.92                 broken clouds
# 4          Albany      US  42.60  -73.97                    light rain
# ..            ...     ...    ...     ...                           ...
# 554       Portree      GB  57.41   -6.19                 broken clouds
# 555    Strezhevoy      RU  60.73   77.59               overcast clouds
# 556        Artyom      AZ  40.47   50.33  thunderstorm with light rain
# 557      Kirkwood      US  38.58  -90.41                 broken clouds
# 558       Astoria      US  46.19 -123.83                 broken clouds
#
#      Rain (inches)  Snow (inches)  Max Temp  Humidity  Cloudiness  Wind Speed
# 0             0.00           0.00     53.22        94          77        3.83
# 1             0.00           0.00     42.39        79          98       18.57
# 2             0.00           0.00     77.00        69          75       20.80
# 3             0.00           0.00     35.60        93          75       11.41
# 4             0.11           0.11     87.01        53          71        1.01
# ..             ...            ...       ...       ...         ...         ...
# 554           0.00           0.00     55.99        91          72        8.01
# 555           0.00           0.00     46.40        70         100        4.47
# 556           0.00           0.00     78.80        50          40       16.11
# 557           0.00           0.00     89.60        38          75       11.41
# 558           0.00           0.00     75.00        82          75       17.22
#
# [559 rows x 11 columns]

# %%
raining_cities=city_data_df.loc[city_data_df["Rain (inches)"]>0]
raining_cities
# Out:
#           City Country    Lat     Lng Current Description  Rain (inches)  \
# 4       Albany      US  42.60  -73.97          light rain           0.11
# 5        Nauta      PE  -4.51  -73.58          light rain           0.80
# 8       Hobart      AU -42.88  147.33          light rain           0.25
# 16       Kapaa      US  22.08 -159.32       moderate rain           1.27
# 17     Rikitea      PF -23.12 -134.97          light rain           0.18
# ..         ...     ...    ...     ...                 ...            ...
# 518    La Peca      PE  -5.61  -78.44          light rain           0.16
# 527   Maragogi      BR  -9.01  -35.22       moderate rain           1.68
# 540    Longyan      CN  25.11  117.02     very heavy rain          40.39
# 549       Wuan      CN  31.68  112.00          light rain           0.15
# 550  Parintins      BR  -2.63  -56.74          light rain           0.15
#
#      Snow (inches)  Max Temp  Humidity  Cloudiness  Wind Speed
# 4             0.11     87.01        53          71        1.01
# 5             0.80     77.56        85          81        4.12
# 8             0.25     42.01        93          40        1.59
# 16            1.27     82.99        83          75       17.22
# 17            0.18     74.61        82         100       20.94
# ..             ...       ...       ...         ...         ...
# 518           0.16     73.49        72          15        3.96
# 527           1.68     76.19        86          84       13.24
# 540          40.39     82.99        71         100        1.81
# 549           0.15     70.97        86          96        3.20
# 550           0.15     79.11        79          89        1.39
#
# [64 rows x 11 columns]

# %%
snowing_cities=city_data_df.loc[city_data_df["Snow (inches)"]>0]
snowing_cities
# Out:
#           City Country    Lat     Lng Current Description  Rain (inches)  \
# 4       Albany      US  42.60  -73.97          light rain           0.11
# 5        Nauta      PE  -4.51  -73.58          light rain           0.80
# 8       Hobart      AU -42.88  147.33          light rain           0.25
# 16       Kapaa      US  22.08 -159.32       moderate rain           1.27
# 17     Rikitea      PF -23.12 -134.97          light rain           0.18
# ..         ...     ...    ...     ...                 ...            ...
# 518    La Peca      PE  -5.61  -78.44          light rain           0.16
# 527   Maragogi      BR  -9.01  -35.22       moderate rain           1.68
# 540    Longyan      CN  25.11  117.02     very heavy rain          40.39
# 549       Wuan      CN  31.68  112.00          light rain           0.15
# 550  Parintins      BR  -2.63  -56.74          light rain           0.15
#
#      Snow (inches)  Max Temp  Humidity  Cloudiness  Wind Speed
# 4             0.11     87.01        53          71        1.01
# 5             0.80     77.56        85          81        4.12
# 8             0.25     42.01        93          40        1.59
# 16            1.27     82.99        83          75       17.22
# 17            0.18     74.61        82         100       20.94
# ..             ...       ...       ...         ...         ...
# 518           0.16     73.49        72          15        3.96
# 527           1.68     76.19        86          84       13.24
# 540          40.39     82.99        71         100        1.81
# 549           0.15     70.97        86          96        3.20
# 550           0.15     79.11        79          89        1.39
#
# [64 rows x 11 columns]

# %%
# Create the output file (CSV).
output_data_file = "Challenge_Submissions/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
